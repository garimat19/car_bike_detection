# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16614, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 16614 (delta 48), reused 56 (delta 27), pack-reused 16522
# Receiving objects: 100% (16614/16614), 15.14 MiB | 21.06 MiB/s, done.
# Resolving deltas: 100% (11401/11401), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 41.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.9/756.9 kB 62.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.3.0 which is incompatible.
# ...

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AKBEq7Ejbl39jB44A5Fi")
project = rf.workspace("object-detection-crzpu").project("twowheeler_fourwheeler")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/twowheeler_fourwheeler-1 in yolov5pytorch:: 100%|██████████| 974/974 [00:00<00:00, 5150.36it/s]

# %%
# !python train.py --img 416 --batch 4 --epochs 80 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-05-14 08:37:36.591794: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-14 08:37:36.591851: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-14 08:37:36.593380: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# source /path ---> images
# source 0 -----> webcam
# source /path of video
# source ---> url of youtube

# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/datasets/twowheeler_fourwheeler-1/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-312-g1bcd17ee Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/34 /content/datasets/twowheeler_fourwheeler-1/test/images/download-13-_jpg.rf.d913ef6605606c3d89dcd6d37eb0c44d.jpg: 416x416 1 bikes, 7.1ms
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/datasets/twowheeler_fourwheeler-1/test/images/images-97-_jpg.rf.5407702d491a9c697d3f13a01c17d6a4.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/datasets/twowheeler_fourwheeler-1/test/images/images-97-_jpg.rf.5407702d491a9c697d3f13a01c17d6a4.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-312-g1bcd17ee Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/datasets/twowheeler_fourwheeler-1/test/images/images-97-_jpg.rf.5407702d491a9c697d3f13a01c17d6a4.jpg: 416x416 2 cars, 7.1ms
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source //content/datasets/twowheeler_fourwheeler-1/test/images/download-13-_jpg.rf.d913ef6605606c3d89dcd6d37eb0c44d.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=//content/datasets/twowheeler_fourwheeler-1/test/images/download-13-_jpg.rf.d913ef6605606c3d89dcd6d37eb0c44d.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-312-g1bcd17ee Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/datasets/twowheeler_fourwheeler-1/test/images/download-13-_jpg.rf.d913ef6605606c3d89dcd6d37eb0c44d.jpg: 416x416 1 bikes, 7.1ms
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /2011_MotorBeam_Awards.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/2011_MotorBeam_Awards.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-312-g1bcd17ee Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 312, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 307, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source / images (10).jpg
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source / images (10).jpg'

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /how-to-calculate-on-road-price.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/how-to-calculate-on-road-price.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-312-g1bcd17ee Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 312, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 307, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
# ...
